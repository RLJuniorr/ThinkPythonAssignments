# %% [markdown]
# <a href="https://colab.research.google.com/github/RLJuniorr/ThinkPythonAssignments/blob/main/Week%2013/Week%2013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# NONE


# FUNCTION DEFINITIONS

# write_entry function
# - accepts filename and entry as parameters
# - open file in append mode ('a')
# - write the entry to the file
# - make sure to add '\n' so each entry is on a new line
# - close the file

# read_journal function
# - accepts filename as parameter
# - open file in read mode ('r')
# - read all contents of the file
# - print contents to the screen
# - close the file
# - use try/except to handle FileNotFoundError if file doesn't exist yet


# PROGRAM LOGIC

# set filename to "journal.txt"

# start a while loop that runs until user types "quit"

    # ask user: (W)rite, (R)ead, or (Q)uit?

    # if user chooses 'w':
        # ask for journal entry
        # call write_entry function
        # print confirmation message

    # if user chooses 'r':
        # call read_journal function

    # if user chooses 'q':
        # break the loop and end program

    # otherwise:
        # print invalid input message
