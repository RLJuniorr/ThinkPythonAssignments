# %% [markdown]
# <a href="https://colab.research.google.com/github/RLJuniorr/ThinkPythonAssignments/blob/main/Week%2016/%20Weel%2016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
expenses = []

while True:
    print("\n--- Expense Tracker ---")
    print("1. Add New Expense")
    print("2. Get Totals")
    print("3. Exit")

    choice = input("Selection: ")

    if choice == "1":
        category = input("Enter Category: ")
        vendor = input("Enter Vendor: ")

        try:
            amount = float(input("Enter Amount: "))
        except:
            print("Invalid amount. Try again.")
            continue

        date = input("Enter Date (YYYY-MM-DD): ")

        expense = {
            "category": category,
            "vendor": vendor,
            "amount": amount,
            "date": date
        }

        expenses.append(expense)
        print("Expense added!")

    elif choice == "2":
        print("\nCurrent Expenses List:")
        for e in expenses:
            print(e)

    elif choice == "3":
        print("Goodbye!")
        break

    else:
        print("Invalid selection.")
