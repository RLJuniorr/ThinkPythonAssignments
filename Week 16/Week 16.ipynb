# %% [markdown]
# <a href="https://colab.research.google.com/github/RLJuniorr/ThinkPythonAssignments/blob/main/Week%2016/Week%2016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create an empty list called expenses to store all expense records

# Each expense will be a dictionary with:
#   category, vendor, amount, date

# Start a main loop that keeps running until the user chooses to exit
#   Display menu:
#       1. Add New Expense
#       2. Get Totals
#       3. Exit

#   If user chooses 1:
#       Ask for category, vendor, amount, date
#       Store them in a dictionary
#       Add dictionary to expenses list

#   If user chooses 2:
#       Show total options:
#           A: All expenses
#           C: Filter by category
#           V: Filter by vendor

#       If A:
#           Loop through all expenses
#           Add all amounts

#       If C:
#           Ask for category
#           Loop through expenses
#           Only add amounts where category matches

#       If V:
#           Ask for vendor
#           Loop through expenses
#           Only add amounts where vendor matches

#   If user chooses 3:
#       End program

# Filtering idea:
#   for each expense in expenses:
#       if expense["category"] == user_input:
#           add expense["amount"]
