# %% [markdown]
# <a href="https://colab.research.google.com/github/RLJuniorr/ThinkPythonAssignments/blob/main/Week%2014/%20Week%2014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# NONE


# CLASS DEFINITIONS
class Book:
    # __init__ method
    # - takes in title and author
    # - sets self.title = title
    # - sets self.author = author
    # - sets self.is_available = True

    # __str__ method
    # - if book is available → show "Available"
    # - otherwise → show "Checked Out"
    # - return formatted string: "title by author - status"

    # checkout method
    # - set self.is_available to False

    # return_book method
    # - set self.is_available to True


# PROGRAM LOGIC
# - create at least two Book objects
# - print both books
# - call checkout() on one book
# - print both books again to show change
