# %% [markdown]
# <a href="https://colab.research.google.com/github/RLJuniorr/ThinkPythonAssignments/blob/main/Week%2014/Week%2014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# NONE


# CLASS DEFINITIONS
class Book:
    # __init__ method that sets title, author, and availability
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.is_available = True

    # __str__ method for user-friendly display
    def __str__(self):
        if self.is_available:
            status = "Available"
        else:
            status = "Checked Out"
        return f"{self.title} by {self.author} - {status}"

    # method to check out a book
    def checkout(self):
        self.is_available = False

    # method to return a book
    def return_book(self):
        self.is_available = True


# PROGRAM LOGIC
# Create at least two book objects
book1 = Book("Think Python", "Allen Downey")
book2 = Book("The Hobbit", "J.R.R. Tolkien")

# Print initial status
print("--- Library Status ---")
print(book1)
print(book2)

# Check out one book
print("\nChecking out 'The Hobbit'...")
book2.checkout()

# Print updated status
print("\n--- Updated Status ---")
print(book1)
print(book2)
