# %% [markdown]
# <a href="https://colab.research.google.com/github/RLJuniorr/ThinkPythonAssignments/blob/main/Week%203/Week%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is a Python program to demonstrate variables and statements

money_in_wallet = 15
money_in_bank = 100

total_money = money_in_wallet + money_in_bank
print(money_in_wallet)
print(money_in_bank)
print(total_money)


ehi = 15
hfewh = 100

huwfgweh = ehi + hfewh
print(ehi)
print(hfewh)
print(huwfgweh)
# Out:
# 15
# 100
# 115
# 15
# 100
# 115
